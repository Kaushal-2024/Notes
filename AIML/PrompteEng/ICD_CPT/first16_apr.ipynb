# %%
[{'role': 'system',
  'content': '\nYou are a medical assistant specializing in dermatology. Analyze a patient-dermatologist conversation transcript and extract pertinent **clinical history** for dermatological assessment, presented in a structured format. Include the onset or duration of each relevant history item, if available, and indicate if the problem is ongoing and whether it is currently being treated.\n\n### Extract the following fields (if mentioned in the transcript):\n\n- `"chief_complaint"`: The patient\'s primary skin-related concern and the date or time it began.\n- `"hpi"`: History of Present Illness – a detailed narrative and timeline of the current dermatological issue (duration, changes, previous treatments, etc.). Include specific dates or durations mentioned, whether the issue is ongoing, and whether it is currently being treated.\n- `"cancer_history"`: Personal history of skin cancer or other cancers, including diagnosis dates or approximate timeframes, whether any related issues are ongoing, and whether they are currently being treated.\n- `"skin_history"`: Previous or chronic skin conditions (e.g., eczema, acne, psoriasis), including onset or duration if available, whether the condition is ongoing, and whether it is currently being treated.\n- `"allergies"`: Known skin or drug-related allergies, including the type of allergen, reaction, and when the allergy was identified.\n- `"social_history"`: Lifestyle factors relevant to dermatology (e.g., sun exposure, smoking, occupational exposures, hygiene practices), with timeframes or durations if mentioned.\n\nOnly include dermatology-relevant information. If a section is not mentioned in the transcript, omit it or return it with the value `"not mentioned"`. If durations are not mentioned, ignore them. If there is no current treatment related to a condition, mark it as "completed". If it is currently being treated, mark it as "current".\n\n### Return Output in the Following JSON Format:\n\n```json\n{\n  "chief_complaint": "",\n  "hpi": "",\n  "cancer_history": "",\n  "skin_history": "",\n  "allergies": "",\n  "social_history": ""\n}\n'},
 {'role': 'user',
  'content': '\nMedical Transcript to Analyze:\n\n[\'Dr. Adrian: Hi, Robert Durkee, sixty-nine. New patient here for a skin check.; 0.48-6.72s\', \'Robert: Yes.; 6.96-7.76s\', \'Dr. Adrian: Yes. And for two.; 7.76-9.52s\', \'Dr. Adrian: Hello. Is this Robert?; 13.275-14.475s\', \'Robert: Yes, it is.; 14.475-15.035s\', \'Dr. Adrian: Robert, Dr. Adrian. Good to meet you.; 15.035-16.955s\', \'Dr. Adrian: Have a seat. Okay.; 17.275-18.875s\', \'Dr. Adrian: Where are you from, Robert?; 19.275-20.635s\', \'Robert: Emory.; 20.635-23.835s\', \'Dr. Adrian: Oh, Emory? Yeah.; 23.835-29.28s\', \'Dr. Adrian: Good to meet you. How was the drive? Good day. Are you going to Richfield often?; 29.28-34.32s\', "Robert: This is the doctor\'s office. We visit Dr. Pope, our main doctor.; 35.6-41.025s", \'Dr. Adrian: Oh, yeah. I know Dr. Pope. I used to live nearby him too, and I moved to Richfield, but he lives in Central. But, yeah, I know Dr. Pope. So what do we do for you today, Robert?; 41.025-51.585s\', \'Robert: I have a few spots on my head that need to be looked at.; 51.87-54.75s\', "Dr. Adrian: Let\'s take a look. Have you ever seen a skin doctor before?; 54.75-61.07s", \'Robert: No.; 61.07-78.905s\', "Dr. Adrian: Okay. So, yeah, there are some small, rough, scaly papules we call them, or little rough spots on the crown of your scalp. Mhmm. And they\'re called actinic keratosis.; 61.07-78.905s", "Dr. Adrian: They\'re little precancerous lesions. Think of it like weeds in a garden. Not a huge deal, but they\'re little weeds that can become bad when they start to grow too big, so we just have to treat them to kill them.; 79.145-95.965s", \'Dr. Adrian: I think the TCA thirty-five is going to be used. There are approximately about ten little bitty ones throughout.; 95.965-106.05s\', "Dr. Adrian: So I\'m going to put a chemical on it to make them peel. It\'s going to hurt a little, it\'s going to get red, and they\'re going to peel off like a sunburn.; 106.05-128.705s", "Dr. Adrian: Rather than burning individual ones, I\'m just going to treat the whole area. We\'re going to do a total of ten actinic keratosis treatments with TCA, or trichloroacetic acid, thirty-five percent.; 129.585-154.625s", "Dr. Adrian: This is going to hurt just a tiny bit, okay? Not at first, you\'re just going to feel wet.; 154.785-155.825s", \'Robert: Just wet.; 155.825-159.985s\', "Dr. Adrian: Okay. Well, I\'ll know we just have to put maybe a couple more layers on until it starts to get white. Alright. How\'s the feeling?; 197.32-237.095s", \'Robert: Okay.; 409.05-409.37s\', \'Dr. Adrian: So there is actually a total of about twenty actinic keratosis on the crown instead of ten.; 439.22-447.46s\']\n'}]

# %% [markdown]
# ```
# {
#   "chief_complaint": "Rough, scaly spots on the scalp; date of onset not specified.",
#   "hpi": "Robert Durkee, age 69, presented as a new patient for a skin check. He reported a few spots on his head needing evaluation. On examination, Dr. Adrian identified approximately twenty rough, scaly papules on the crown of the scalp, diagnosed as actinic keratoses. These are precancerous lesions that may worsen if left untreated. This is Robert’s first visit to a skin doctor. The treatment plan includes chemical peeling using 35% trichloroacetic acid (TCA) to remove the lesions. The treatment is currently being administered during the visit.",
#   "cancer_history": "not mentioned",
#   "skin_history": "No prior skin conditions mentioned; this is the patient's first dermatology visit.",
#   "allergies": "not mentioned",
#   "social_history": "not mentioned"
# }

# %%
[{'role': 'system',
  'content': '\nYou are a medical language model specialized in dermatology. Your task is to extract **as many possible diagnoses** as you can from a dermatology consultation transcript. This includes:\n\n### Diagnosis Extraction\n1. Identify the **primary diagnosis** explicitly given by the clinician.\n\n### Alternative and Assumed Diagnoses\n2. Extract **alternative or differential diagnoses**, even if mentioned tentatively or dismissed.\n3. Infer any **implied or assumed diagnoses** based on symptoms, patterns, or phrases.\n\n### Symptom-Based Diagnoses\n4. Treat each **distinct symptom** as a potential standalone diagnosis when relevant (e.g., “chronic itching” → *Pruritus*).\n\n### Sub-Diagnosis Extraction\n5. For every diagnosis, try to identify and extract any **sub-diagnoses**, complications, or associated conditions:\n- If sub-diagnoses are **not explicitly mentioned**, intelligently **assume them** based on known medical relationships and context in the transcript.\n\n\n**Output Format**:\nFor each diagnosis or sub-diagnosis, follow this structure:\n\n**Diagnosis Name:**\n**Reasoning / Transcript Reference:** (cite phrases or implied reasoning)\n\nBe exhaustive and opportunistic — the goal is to **maximize the retrieval of all diagnostic possibilities**, even if they are speculative, symptom-derived, or implied by context.\n'},
 {'role': 'user',
  'content': '\n## HISTORY\n  {\'chief_complaint\': \'Rough, scaly spots on the scalp; date of onset not specified.\', \'hpi\': \'Robert Durkee, age 69, presented as a new patient for a skin check. He reported a few spots on his head needing evaluation. On examination, Dr. Adrian identified approximately twenty rough, scaly papules on the crown of the scalp, diagnosed as actinic keratoses. These are precancerous lesions that may worsen if left untreated. This is Robert’s first visit to a skin doctor. The treatment plan includes chemical peeling using 35% trichloroacetic acid (TCA) to remove the lesions. The treatment is currently being administered during the visit.\', \'cancer_history\': \'not mentioned\', \'skin_history\': "No prior skin conditions mentioned; this is the patient\'s first dermatology visit.", \'allergies\': \'not mentioned\', \'social_history\': \'not mentioned\'}\n'}]
# Out:
# [{'role': 'system',
# ...

# %% [markdown]
# **Primary Diagnosis:**
# **Actinic Keratosis (AK)**
# **Reasoning / Transcript Reference:** “Dr. Adrian identified approximately twenty rough, scaly papules on the crown of the scalp, diagnosed as actinic keratoses. These are precancerous lesions...” — This is explicitly stated as the diagnosis by the clinician.
#
# ---
#
# **Implied / Sub-Diagnosis:**
# **Precancerous Skin Lesions / Cutaneous Squamous Cell Carcinoma in situ (potential progression)**
# **Reasoning / Transcript Reference:** “They’re little precancerous lesions… that can become bad when they start to grow too big” — Actinic keratosis is a known precursor to squamous cell carcinoma. The clinician indicates potential for malignant transformation.
#
# ---
#
# **Symptom-Based Diagnosis:**
# **Scalp Xerosis / Scaling Dermatosis**
# **Reasoning / Transcript Reference:** “Rough, scaly papules on the crown of your scalp” — These descriptors indicate dry, keratotic skin lesions, which could also fall under xerotic or scaling dermatoses.
#
# ---
#
# **Inferred / Implied Diagnosis:**
# **Chronic Sun Damage / Photoaging**
# **Reasoning / Transcript Reference:** Actinic keratoses are caused by cumulative UV exposure. The presence of multiple lesions on the scalp in a 69-year-old male strongly implies chronic sun damage.
#
# ---
#
# **Inferred / Sub-Diagnosis (Associated Condition):**
# **Field Cancerization**
# **Reasoning / Transcript Reference:** The use of field therapy (TCA over the entire crown) instead of spot treatment implies field cancerization — a concept where multiple subclinical lesions exist due to widespread sun damage.
#
# ---

# %%
[{'role': 'system',
  'content': '\nYou are a clinical coding assistant specialized in dermatology. Your role is to assign **highly specific and clinically justified ICD-10-CM codes** using expert-level dermatologic reasoning.\n\n### INPUT\n\nYou will receive:\n\n- `"medical_info"`: A structured dataset of dermatologic findings that includes:\n  - Diagnosed or suspected conditions\n  - Anatomical sites\n  - Causes or triggers\n  - Severity\n  - Encounter type\n  - Additional context (e.g., relevant history, signs, or symptoms)\n\n### TASK INSTRUCTIONS\n\n1. **Assign ICD-10-CM Codes for All Conditions**\n   - For each unique dermatologic condition (explicit or implied), assign the **most specific ICD-10-CM code available**, including laterality, severity, and encounter type if applicable.\n   - Use combination codes where available; otherwise, assign multiple codes to reflect the clinical complexity.\n\n2. **Infer and Expand Diagnostic Coverage**\n   - Apply expert dermatologic reasoning to infer additional skin conditions or symptoms **commonly associated** with the input.\n   - Assume related or co-occurring conditions **if medically plausible** based on morphology, distribution, chronicity, or pathophysiology.\n   - Treat all inferred conditions as independent and code-worthy diagnoses.\n   - Use **distinct terminology** to reflect clinical nuance (e.g., expand “rash” to “macules,” “papules,” “erythema,” etc.).\n\n3. **Extract Minor, Suspected, and Incidental Findings**\n   - Code **any minor, secondary, or suspected** dermatologic condition if it may affect treatment, prognosis, or follow-up — even if not the primary reason for the encounter.\n\n4. **Justify Every Code**\n   - For every ICD-10-CM code, provide a clinical justification based on:\n     - Direct evidence from `medical_info`\n     - Reasonable dermatologic inference based on presentation, comorbidities, or classic associations\n   - Clearly label inferred items with “clinically inferred” and explain the reasoning (e.g., “likely co-occurs with seborrheic dermatitis on scalp”).\n\n\n### CLINICAL STRATEGY\n\n- Think like a dermatologist coding for both completeness and clinical accuracy.\n- Consider:\n  - Morphology (lesion type and characteristics)\n  - Distribution (site-specific vs generalized)\n  - Chronicity and severity\n  - Etiologic patterns (e.g., allergic, infectious, autoimmune)\n- Reconstruct the **entire dermatologic picture**, including conditions **not explicitly mentioned but strongly implied**.\n\n\n### OUTPUT FORMAT (JSON)\n\n```json\n{\n  "icd10": [\n    {\n      "code": "[ICD-10-CM code]",\n      "name": "[ICD-10-CM title]",\n      "condition": "[Clinically specific term]",\n      "description": "[ICD-10-CM official description]",\n      "location": "[Anatomical site(s)]",\n      "reason": "[Justification — direct or inferred from medical_info]"\n    }\n    // Repeat for each coded condition\n  ]\n}\n'},
 {'role': 'user',
  'content': '\n## EXTRACTED INFORMATION\n  **Primary Diagnosis:**  \n**Actinic Keratosis (AK)**  \n**Reasoning / Transcript Reference:** “Dr. Adrian identified approximately twenty rough, scaly papules on the crown of the scalp, diagnosed as actinic keratoses. These are precancerous lesions...” — This is explicitly stated as the diagnosis by the clinician.\n\n---\n\n**Implied / Sub-Diagnosis:**  \n**Precancerous Skin Lesions / Cutaneous Squamous Cell Carcinoma in situ (potential progression)**  \n**Reasoning / Transcript Reference:** “They’re little precancerous lesions… that can become bad when they start to grow too big” — Actinic keratosis is a known precursor to squamous cell carcinoma. The clinician indicates potential for malignant transformation.\n\n---\n\n**Symptom-Based Diagnosis:**  \n**Scalp Xerosis / Scaling Dermatosis**  \n**Reasoning / Transcript Reference:** “Rough, scaly papules on the crown of your scalp” — These descriptors indicate dry, keratotic skin lesions, which could also fall under xerotic or scaling dermatoses.\n\n---\n\n**Inferred / Implied Diagnosis:**  \n**Chronic Sun Damage / Photoaging**  \n**Reasoning / Transcript Reference:** Actinic keratoses are caused by cumulative UV exposure. The presence of multiple lesions on the scalp in a 69-year-old male strongly implies chronic sun damage.\n\n---\n\n**Inferred / Sub-Diagnosis (Associated Condition):**  \n**Field Cancerization**  \n**Reasoning / Transcript Reference:** The use of field therapy (TCA over the entire crown) instead of spot treatment implies field cancerization — a concept where multiple subclinical lesions exist due to widespread sun damage.\n\n---\n\nLet me know if you’d like to generate patient education summaries or billing codes (e.g., ICD-10) for these diagnoses.\n'}]
# Out:
# [{'role': 'system',
# ...

# %% [markdown]
# ```
# {
#   "icd10": [
#     {
#       "code": "L57.0",
#       "name": "Actinic keratosis",
#       "condition": "Actinic keratosis",
#       "description": "Actinic keratosis",
#       "location": "Crown of scalp",
#       "reason": "Explicit diagnosis made by clinician due to presence of ~20 rough, scaly papules; confirmed as actinic keratoses."
#     },
#     {
#       "code": "Z85.828",
#       "name": "Personal history of other malignant neoplasm of skin",
#       "condition": "Risk of progression to squamous cell carcinoma",
#       "description": "Personal history of other malignant neoplasm of skin",
#       "location": "Scalp (field of actinic keratoses)",
#       "reason": "Actinic keratosis is a known precancerous lesion with potential to evolve into squamous cell carcinoma. This code documents the precancerous nature and justifies dermatologic surveillance."
#     },
#     {
#       "code": "L85.3",
#       "name": "Xerosis cutis",
#       "condition": "Scalp xerosis / dry scaling dermatosis",
#       "description": "Xerosis cutis",
#       "location": "Crown of scalp",
#       "reason": "Clinically inferred based on descriptive terms: 'rough', 'scaly'. These are common with actinic damage and may complicate healing post-chemical peel."
#     },
#     {
#       "code": "L57.8",
#       "name": "Other skin changes due to chronic exposure to nonionizing radiation",
#       "condition": "Chronic sun damage / photoaging",
#       "description": "Other skin changes due to chronic exposure to nonionizing radiation",
#       "location": "Crown of scalp",
#       "reason": "Inferred from the diagnosis of actinic keratoses in an elderly male; reflects underlying chronic photodamage from cumulative UV exposure."
#     },
#     {
#       "code": "D48.5",
#       "name": "Neoplasm of uncertain behavior of skin",
#       "condition": "Field cancerization",
#       "description": "Neoplasm of uncertain behavior of skin",
#       "location": "Crown of scalp",
#       "reason": "Clinically inferred due to widespread area-based TCA treatment. Field cancerization indicates multiple subclinical lesions with malignant potential."
#     },
#     {
#       "code": "Z01.818",
#       "name": "Encounter for other preprocedural examination",
#       "condition": "Pre-procedural evaluation for chemical peel (TCA)",
#       "description": "Encounter for other preprocedural examination",
#       "location": "N/A",
#       "reason": "Justifies visit context — new patient presenting for full skin check and receiving chemical peel treatment during encounter."
#     }
#   ]
# }

# %%
[{'role': 'system',
  'content': '\n**SYSTEM PROMPT TO EXTRACT ICD-10 FAMILY / SISTER CODES:**\n\nYou are a clinical coding assistant trained in ICD-10 structure and disease classification. Your task is to take a list of ICD-10 codes and return a list of their **related codes**, including:\n\n### Sister / Family ICD-10 Codes\nFor each input ICD-10 code:\n1. Identify **sibling codes** (codes with the same 3-character root and different suffixes).\n2. Include **parent category** and **sub-category codes** when applicable.\n3. Suggest **closely related codes** based on disease similarity, shared etiology, or classification in the ICD-10 hierarchy.\n\n\n**For each input ICD-10 code, output the following:**\n\n**Input ICD-10 Code:**\n**Description:**\n\n**Sister ICD-10 Codes:**\n- **Code:**\n- **Description:**\n- **Relation Type:** Sibling / Subtype / Parent / Related Category\n\nInclude as many relevant related codes as possible, referencing their placement in the ICD-10 taxonomy or clinical similarity.\n\nBe exhaustive. The goal is to create a complete view of related ICD codes that could be used for:\n- Expanded clinical documentation\n- Alternative coding\n- Billing optimization\n- Diagnostic exploration\n\nRely on the ICD-10 structure and logical disease grouping to infer relationships when not explicitly stated.\n\n### REQUIRED OUTPUT FORMAT\n\nReturn your output in the following strict JSON structure:\n\n{\n    "icd10": [\n        {\n            "code": "[ICD-10-CM code for Clinical diagnosis]",\n            "name": "[Name according to ICD-10-CM code]",\n            "condition": "[Clinical diagnosis name]",\n            "description": "[Official ICD-10-CM code description]",\n            "relation_type": Sibling / Modifier Variant / Parent Category / Alternate Procedure\n            "relation_with": The initial code from which these connections are made[Base ICD Code for Relationships].\n            "location": "[Affected site(s), comma-separated if multiple]",\n            "reason": "[Why this ICD-10 code applies, citing evidence from medical_info]"\n        }\n        // Additional entries for other dermatological conditions\n    ]\n}\n'},
 {'role': 'user',
  'content': '\n## ICD-10-CM CODES\n    {\n    "icd10": [\n      {\n        "code": "L57.0",\n        "name": "Actinic keratosis",\n        "condition": "Actinic keratosis",\n        "description": "Actinic keratosis",\n        "location": "Crown of scalp",\n        "reason": "Explicit diagnosis made by clinician due to presence of ~20 rough, scaly papules; confirmed as actinic keratoses."\n      },\n      {\n        "code": "Z85.828",\n        "name": "Personal history of other malignant neoplasm of skin",\n        "condition": "Risk of progression to squamous cell carcinoma",\n        "description": "Personal history of other malignant neoplasm of skin",\n        "location": "Scalp (field of actinic keratoses)",\n        "reason": "Actinic keratosis is a known precancerous lesion with potential to evolve into squamous cell carcinoma. This code documents the precancerous nature and justifies dermatologic surveillance."\n      },\n      {\n        "code": "L85.3",\n        "name": "Xerosis cutis",\n        "condition": "Scalp xerosis / dry scaling dermatosis",\n        "description": "Xerosis cutis",\n        "location": "Crown of scalp",\n        "reason": "Clinically inferred based on descriptive terms: \'rough\', \'scaly\'. These are common with actinic damage and may complicate healing post-chemical peel."\n      },\n      {\n        "code": "L57.8",\n        "name": "Other skin changes due to chronic exposure to nonionizing radiation",\n        "condition": "Chronic sun damage / photoaging",\n        "description": "Other skin changes due to chronic exposure to nonionizing radiation",\n        "location": "Crown of scalp",\n        "reason": "Inferred from the diagnosis of actinic keratoses in an elderly male; reflects underlying chronic photodamage from cumulative UV exposure."\n      },\n      {\n        "code": "D48.5",\n        "name": "Neoplasm of uncertain behavior of skin",\n        "condition": "Field cancerization",\n        "description": "Neoplasm of uncertain behavior of skin",\n        "location": "Crown of scalp",\n        "reason": "Clinically inferred due to widespread area-based TCA treatment. Field cancerization indicates multiple subclinical lesions with malignant potential."\n      },\n      {\n        "code": "Z01.818",\n        "name": "Encounter for other preprocedural examination",\n        "condition": "Pre-procedural evaluation for chemical peel (TCA)",\n        "description": "Encounter for other preprocedural examination",\n        "location": "N/A",\n        "reason": "Justifies visit context — new patient presenting for full skin check and receiving chemical peel treatment during encounter."\n      }\n    ]\n  }\n\n'}]

# %% [markdown]
# ```
# {
#   "icd10": [
#     {
#       "code": "L57.1",
#       "name": "Actinic reticuloid",
#       "condition": "Actinic reticuloid",
#       "description": "Actinic reticuloid",
#       "relation_type": "Sibling",
#       "relation_with": "L57.0",
#       "location": "Exposed skin (typically face and scalp)",
#       "reason": "Shares same L57 root; also a chronic photodermatosis due to UV radiation."
#     },
#     {
#       "code": "L57.2",
#       "name": "Poikiloderma of Civatte",
#       "condition": "Poikiloderma of Civatte",
#       "description": "Poikiloderma of Civatte",
#       "relation_type": "Sibling",
#       "relation_with": "L57.0",
#       "location": "Neck and lateral face",
#       "reason": "Related to chronic sun damage; within L57 family of nonionizing radiation-induced skin changes."
#     },
#     {
#       "code": "L57.4",
#       "name": "Cutis rhomboidalis nuchae",
#       "condition": "Cutis rhomboidalis nuchae",
#       "description": "Cutis rhomboidalis nuchae",
#       "relation_type": "Sibling",
#       "relation_with": "L57.0",
#       "location": "Posterior neck",
#       "reason": "Also due to chronic UV exposure; categorized under same L57 group."
#     },
#     {
#       "code": "L57.5",
#       "name": "Solar elastosis",
#       "condition": "Solar elastosis",
#       "description": "Solar elastosis",
#       "relation_type": "Sibling",
#       "relation_with": "L57.0",
#       "location": "Sun-exposed skin",
#       "reason": "Represents degeneration of elastic tissue from sun damage, closely related to AK."
#     },
#     {
#       "code": "Z85.820",
#       "name": "Personal history of malignant melanoma of skin",
#       "condition": "Personal history of melanoma",
#       "description": "Personal history of malignant melanoma of skin",
#       "relation_type": "Sibling",
#       "relation_with": "Z85.828",
#       "location": "Skin",
#       "reason": "Shares Z85.82 prefix; documents history of specific malignant skin neoplasm (melanoma)."
#     },
#     {
#       "code": "Z85.821",
#       "name": "Personal history of basal cell carcinoma of skin",
#       "condition": "Personal history of basal cell carcinoma",
#       "description": "Personal history of basal cell carcinoma of skin",
#       "relation_type": "Sibling",
#       "relation_with": "Z85.828",
#       "location": "Skin",
#       "reason": "Variant of skin cancer history in Z85.82 family; relevant given AK can co-occur with BCC."
#     },
#     {
#       "code": "L85.0",
#       "name": "Acquired ichthyosis",
#       "condition": "Acquired ichthyosis",
#       "description": "Acquired ichthyosis",
#       "relation_type": "Sibling",
#       "relation_with": "L85.3",
#       "location": "Generalized skin",
#       "reason": "Related L85 code for acquired dry, scaly skin conditions — similar etiology of hyperkeratosis."
#     },
#     {
#       "code": "L85.1",
#       "name": "Pityriasis simplex",
#       "condition": "Pityriasis simplex",
#       "description": "Pityriasis simplex",
#       "relation_type": "Sibling",
#       "relation_with": "L85.3",
#       "location": "Scalp, trunk",
#       "reason": "Represents another form of scaling skin disorder with dryness and flaking."
#     },
#     {
#       "code": "D48.4",
#       "name": "Neoplasm of uncertain behavior of connective and other soft tissue",
#       "condition": "Uncertain skin-adjacent soft tissue neoplasm",
#       "description": "Neoplasm of uncertain behavior of connective and other soft tissue",
#       "relation_type": "Sibling",
#       "relation_with": "D48.5",
#       "location": "Skin and subcutaneous tissue",
#       "reason": "Shares D48 root; documents neoplasms of uncertain behavior beyond just cutaneous tissue."
#     },
#     {
#       "code": "D04.0",
#       "name": "Carcinoma in situ of skin of lip",
#       "condition": "Carcinoma in situ (skin)",
#       "description": "Carcinoma in situ of skin of lip",
#       "relation_type": "Related Category",
#       "relation_with": "D48.5",
#       "location": "Lip",
#       "reason": "Related pre-invasive cutaneous carcinoma (e.g., Bowen's disease) — potential progression from AK."
#     },
#     {
#       "code": "Z01.810",
#       "name": "Encounter for preprocedural cardiovascular examination",
#       "condition": "Preprocedural cardiovascular exam",
#       "description": "Encounter for preprocedural cardiovascular examination",
#       "relation_type": "Sibling",
#       "relation_with": "Z01.818",
#       "location": "N/A",
#       "reason": "Part of Z01.81 subcategory; shares procedural prep classification for other body systems."
#     },
#     {
#       "code": "Z01.812",
#       "name": "Encounter for preprocedural respiratory examination",
#       "condition": "Preprocedural pulmonary exam",
#       "description": "Encounter for preprocedural respiratory examination",
#       "relation_type": "Sibling",
#       "relation_with": "Z01.818",
#       "location": "N/A",
#       "reason": "Same Z01.81 group; alternate encounter-based evaluations before interventions."
#     }
#   ]
# }

# %%
[{'role': 'system',
  'content': '\nYou are a medical language model trained in clinical documentation and coding. Your task is to extract all **possible CPT (Current Procedural Terminology) codes** from a dermatology transcript.\n\n###  Inputs:\n- A clinical consultation **transcript**\n- One or more **ICD-10 codes**\n\n### Your Goal:\nIdentify every CPT code that could be reasonably associated with:\n1. **Procedures directly mentioned** in the transcript.\n2. **Implied or assumed procedures** based on the symptoms, diagnoses, or clinical actions (e.g., biopsies, cultures, excisions, injections, phototherapy, etc.).\n3. **Standard procedures** that are commonly performed for the given ICD-10 codes — even if not explicitly stated in the transcript.\n\n**For each CPT code, include**:\n- **CPT Code Number**\n- **Procedure Name**\n- **Type:** Directly Mentioned / Implied / ICD-10-Based / Assumed Standard\n- **Reasoning / Reference in Transcript or ICD-10 Link**\n- **Relation Type:** The ICD code that these related codes are derived from.\n- **Associated ICD:** All associated ICD in list if none empty list\n- **Modifiers:** CPT modifiers, if any, as a string. Modifiers : it provide additional information about a procedure or service, without altering the core meaning of the CPT code itself\nBe comprehensive. Assume additional procedures where medically reasonable. Your goal is to **maximize the coverage of all relevant CPT codes** based on the information provided.\n\nOutput your result as valid JSON in the following format:\n\n```\n{\n  "cpt": [\n    {\n      "code": "[CPT code for procedure/service]",\n      "name": "[Procedure Name according to CPT code]",\n      "description": "[Official CPT code description]",\n      "type": Directly Mentioned / Implied / ICD-10-Based / Assumed Standard\n      "reason": "[Why this CPT code applies, citing evidence from transcript]",\n      "modifiers": "[CPT modifiers, if any, as a string]",\n      "associated_ICD": ["[ICD-10-CM code]"]\n    }\n    // Additional entries for other procedures/services\n  ]\n}\n```\n\nUse clinical reasoning to link transcript content and ICD-10 context with appropriate procedural codes.\n\n'},
 {'role': 'user',
  'content': '\n## ICD-10-CM CODES\n      {\n    "icd10": [\n      {\n        "code": "L57.0",\n        "name": "Actinic keratosis",\n        "condition": "Actinic keratosis",\n        "description": "Actinic keratosis",\n        "location": "Crown of scalp",\n        "reason": "Explicit diagnosis made by clinician due to presence of ~20 rough, scaly papules; confirmed as actinic keratoses."\n      },\n      {\n        "code": "Z85.828",\n        "name": "Personal history of other malignant neoplasm of skin",\n        "condition": "Risk of progression to squamous cell carcinoma",\n        "description": "Personal history of other malignant neoplasm of skin",\n        "location": "Scalp (field of actinic keratoses)",\n        "reason": "Actinic keratosis is a known precancerous lesion with potential to evolve into squamous cell carcinoma. This code documents the precancerous nature and justifies dermatologic surveillance."\n      },\n      {\n        "code": "L85.3",\n        "name": "Xerosis cutis",\n        "condition": "Scalp xerosis / dry scaling dermatosis",\n        "description": "Xerosis cutis",\n        "location": "Crown of scalp",\n        "reason": "Clinically inferred based on descriptive terms: \'rough\', \'scaly\'. These are common with actinic damage and may complicate healing post-chemical peel."\n      },\n      {\n        "code": "L57.8",\n        "name": "Other skin changes due to chronic exposure to nonionizing radiation",\n        "condition": "Chronic sun damage / photoaging",\n        "description": "Other skin changes due to chronic exposure to nonionizing radiation",\n        "location": "Crown of scalp",\n        "reason": "Inferred from the diagnosis of actinic keratoses in an elderly male; reflects underlying chronic photodamage from cumulative UV exposure."\n      },\n      {\n        "code": "D48.5",\n        "name": "Neoplasm of uncertain behavior of skin",\n        "condition": "Field cancerization",\n        "description": "Neoplasm of uncertain behavior of skin",\n        "location": "Crown of scalp",\n        "reason": "Clinically inferred due to widespread area-based TCA treatment. Field cancerization indicates multiple subclinical lesions with malignant potential."\n      },\n      {\n        "code": "Z01.818",\n        "name": "Encounter for other preprocedural examination",\n        "condition": "Pre-procedural evaluation for chemical peel (TCA)",\n        "description": "Encounter for other preprocedural examination",\n        "location": "N/A",\n        "reason": "Justifies visit context — new patient presenting for full skin check and receiving chemical peel treatment during encounter."\n      }\n    ]\n  }\n\n## TRANSCRIPT  \n  Dr. Adrian: Hi, Robert Durkee, sixty-nine. New patient here for a skin check.; 0.48-6.72s\n  Robert: Yes.; 6.96-7.76s\n  Dr. Adrian: Yes. And for two.; 7.76-9.52s\n  Dr. Adrian: Hello. Is this Robert?; 13.275-14.475s\n  Robert: Yes, it is.; 14.475-15.035s\n  Dr. Adrian: Robert, Dr. Adrian. Good to meet you.; 15.035-16.955s\n  Dr. Adrian: Have a seat. Okay.; 17.275-18.875s\n  Dr. Adrian: Where are you from, Robert?; 19.275-20.635s\n  Robert: Emory.; 20.635-23.835s\n  Dr. Adrian: Oh, Emory? Yeah.; 23.835-29.28s\n  Dr. Adrian: Good to meet you. How was the drive? Good day. Are you going to Richfield often?; 29.28-34.32s\n  Robert: This is the doctor\'s office. We visit Dr. Pope, our main doctor.; 35.6-41.025s\n  Dr. Adrian: Oh, yeah. I know Dr. Pope. I used to live nearby him too, and I moved to Richfield, but he lives in Central. But, yeah, I know Dr. Pope. So what do we do for you today, Robert?; 41.025-51.585s\n  Robert: I have a few spots on my head that need to be looked at.; 51.87-54.75s\n  Dr. Adrian: Let\'s take a look. Have you ever seen a skin doctor before?; 54.75-61.07s\n  Robert: No.; 61.07-78.905s\n  Dr. Adrian: Okay. So, yeah, there are some small, rough, scaly papules we call them, or little rough spots on the crown of your scalp. Mhmm. And they\'re called actinic keratosis.; 61.07-78.905s\n  Dr. Adrian: They\'re little precancerous lesions. Think of it like weeds in a garden. Not a huge deal, but they\'re little weeds that can become bad when they start to grow too big, so we just have to treat them to kill them.; 79.145-95.965s\n  Dr. Adrian: I think the TCA thirty-five is going to be used. There are approximately about ten little bitty ones throughout.; 95.965-106.05s\n  Dr. Adrian: So I\'m going to put a chemical on it to make them peel. It\'s going to hurt a little, it\'s going to get red, and they\'re going to peel off like a sunburn.; 106.05-128.705s\n  Dr. Adrian: Rather than burning individual ones, I\'m just going to treat the whole area. We\'re going to do a total of ten actinic keratosis treatments with TCA, or trichloroacetic acid, thirty-five percent.; 129.585-154.625s\n  Dr. Adrian: This is going to hurt just a tiny bit, okay? Not at first, you\'re just going to feel wet.; 154.785-155.825s\n  Robert: Just wet.; 155.825-159.985s\n  Dr. Adrian: Okay. Well, I\'ll know we just have to put maybe a couple more layers on until it starts to get white. Alright. How\'s the feeling?; 197.32-237.095s\n  Robert: Okay.; 409.05-409.37s\n  Dr. Adrian: So there is actually a total of about twenty actinic keratosis on the crown instead of ten.; 439.22-447.46s\n'}]

# %% [markdown]
# ```json
# {
#   "cpt": [
#     {
#       "code": "96567",
#       "name": "Photodynamic therapy for skin lesions",
#       "description": "Photodynamic therapy for actinic keratosis; per day",
#       "type": "ICD-10-Based",
#       "reason": "Actinic keratosis (L57.0) is commonly treated using photodynamic therapy; although TCA chemical peel is used here, this code is relevant if light-activated treatments are considered.",
#       "modifiers": "",
#       "associated_ICD": ["L57.0"]
#     },
#     {
#       "code": "17000",
#       "name": "Destruction (e.g., laser surgery, electrosurgery, cryosurgery, chemosurgery) of premalignant lesion",
#       "description": "Destruction of premalignant lesions; first lesion",
#       "type": "Implied",
#       "reason": "TCA 35% chemical peel is a form of chemosurgery used to destroy actinic keratoses (L57.0).",
#       "modifiers": "",
#       "associated_ICD": ["L57.0"]
#     },
#     {
#       "code": "17003",
#       "name": "Destruction of each additional premalignant lesion",
#       "description": "Used in conjunction with 17000; 2–14 lesions",
#       "type": "Implied",
#       "reason": "Twenty actinic keratoses were treated with TCA (chemosurgery), requiring billing for each lesion beyond the first.",
#       "modifiers": "",
#       "associated_ICD": ["L57.0"]
#     },
#     {
#       "code": "99203",
#       "name": "Office or other outpatient visit for a new patient",
#       "description": "New patient evaluation and management; 30–44 minutes",
#       "type": "Directly Mentioned",
#       "reason": "The transcript clearly indicates this is a new patient encounter with detailed history, exam, and treatment planning.",
#       "modifiers": "",
#       "associated_ICD": ["Z01.818"]
#     },
#     {
#       "code": "15788",
#       "name": "Chemical peel, facial; epidermal",
#       "description": "Chemical exfoliation with agents like TCA; for epidermal lesions",
#       "type": "Directly Mentioned",
#       "reason": "Doctor explicitly states use of TCA 35% chemical peel to treat multiple actinic keratoses across the scalp.",
#       "modifiers": "RT",
#       "associated_ICD": ["L57.0", "L85.3", "L57.8"]
#     },
#     {
#       "code": "99213",
#       "name": "Office or other outpatient visit for established patient",
#       "description": "Evaluation and management; 15–29 minutes",
#       "type": "Assumed Standard",
#       "reason": "Follow-up visits after chemical peel or for ongoing monitoring of field cancerization may apply in future.",
#       "modifiers": "",
#       "associated_ICD": ["D48.5", "Z85.828"]
#     },
#     {
#       "code": "11102",
#       "name": "Tangential biopsy of skin",
#       "description": "Tangential biopsy of skin; single lesion",
#       "type": "Assumed Standard",
#       "reason": "Though not directly performed here, biopsy is standard for confirmation or ruling out malignancy in AK or neoplastic areas.",
#       "modifiers": "59",
#       "associated_ICD": ["L57.0", "D48.5"]
#     }
#   ]
# }
# ```

# %%
[{'role': 'system',
  'content': '\n**SYSTEM PROMPT TO EXTRACT CPT SISTER / FAMILY CODES:**\n\nYou are a clinical coding assistant specialized in CPT (Current Procedural Terminology) codes. Your task is to analyze a given CPT code (or a list of them) and return all related **sister/family codes**, using CPT code hierarchy and procedural similarity.\n\n### Sister / Family CPT Code Retrieval\nFor each input CPT code:\n1. Identify **sibling codes** – codes within the same procedural group or code range.\n2. Include **parent category**, **modifiers**, and **alternate code options** if applicable.\n3. Suggest **clinically related procedures** that serve similar diagnostic or therapeutic purposes.\n\n\n**For each CPT code, output the following:**\n\n**Input CPT Code:**\n**Procedure Description:**\n\n**Sister/Family CPT Codes:**\n- **Code:**\n- **Procedure Description:**\n- **Relation Type:** Sibling / Modifier Variant / Parent Category / Alternate Procedure\n- **Modifiers:**  CPT modifiers, if any, as a string. Modifiers : it provide additional information about a procedure or service, without altering the core meaning of the CPT code itself\n- **Relation Type:** The CPT code that these related codes are derived from.\n- **Reasoning:** Explain relationship (e.g., "same code range", "different approach to same procedure", "with vs. without contrast", etc.)\nBe comprehensive. Use both CPT coding structure and clinical context to discover related codes. The goal is to build a **full set of procedural options** for:\n- Clinical decision-making\n- Billing strategy\n- Code optimization\n- Alternative procedural documentation\n\nUse medical reasoning and CPT grouping logic when inferring relationships.\n\n### REQUIRED OUTPUT FORMAT\n\nReturn your output in the following strict JSON structure:\n\n{\n  "cpt": [\n    {\n      "code": "[CPT code for procedure/service]",\n      "name": "[Name according to CPT code]",\n      "description": "[Official CPT code description]",\n      "relation_type": Sibling / Modifier Variant / Parent Category / Alternate Procedure\n      "relation_with": The initial code from which these connections are made[Base CPT Code for Relationships].\n      "reason": "[Why this CPT code applies, citing evidence from transcript]",\n      "modifiers": "[CPT modifiers, if any, as a string]",\n      "associated_ICD": ["[ICD-10-CM code]"]\n    }\n    // Additional entries for other procedures/services\n  ]\n}\n'},
 {'role': 'user',
  'content': '\n## ICD-10-CM CODES\n  {\n  "cpt": [\n    {\n      "code": "96567",\n      "name": "Photodynamic therapy for skin lesions",\n      "description": "Photodynamic therapy for actinic keratosis; per day",\n      "type": "ICD-10-Based",\n      "reason": "Actinic keratosis (L57.0) is commonly treated using photodynamic therapy; although TCA chemical peel is used here, this code is relevant if light-activated treatments are considered.",\n      "modifiers": "",\n      "associated_ICD": ["L57.0"]\n    },\n    { \n      "code": "17000",\n      "name": "Destruction (e.g., laser surgery, electrosurgery, cryosurgery, chemosurgery) of premalignant lesion",\n      "description": "Destruction of premalignant lesions; first lesion",\n      "type": "Implied",\n      "reason": "TCA 35% chemical peel is a form of chemosurgery used to destroy actinic keratoses (L57.0).",\n      "modifiers": "",\n      "associated_ICD": ["L57.0"]\n    },\n    {\n      "code": "17003",\n      "name": "Destruction of each additional premalignant lesion",\n      "description": "Used in conjunction with 17000; 2–14 lesions",\n      "type": "Implied",\n      "reason": "Twenty actinic keratoses were treated with TCA (chemosurgery), requiring billing for each lesion beyond the first.",\n      "modifiers": "",\n      "associated_ICD": ["L57.0"]\n    },\n    {\n      "code": "99203",\n      "name": "Office or other outpatient visit for a new patient",\n      "description": "New patient evaluation and management; 30–44 minutes",\n      "type": "Directly Mentioned",\n      "reason": "The transcript clearly indicates this is a new patient encounter with detailed history, exam, and treatment planning.",\n      "modifiers": "",\n      "associated_ICD": ["Z01.818"]\n    },\n    {\n      "code": "15788",\n      "name": "Chemical peel, facial; epidermal",\n      "description": "Chemical exfoliation with agents like TCA; for epidermal lesions",\n      "type": "Directly Mentioned",\n      "reason": "Doctor explicitly states use of TCA 35% chemical peel to treat multiple actinic keratoses across the scalp.",\n      "modifiers": "RT", \n      "associated_ICD": ["L57.0", "L85.3", "L57.8"]\n    },\n    {\n      "code": "99213",\n      "name": "Office or other outpatient visit for established patient",\n      "description": "Evaluation and management; 15–29 minutes",\n      "type": "Assumed Standard",\n      "reason": "Follow-up visits after chemical peel or for ongoing monitoring of field cancerization may apply in future.",\n      "modifiers": "",\n      "associated_ICD": ["D48.5", "Z85.828"]\n    },\n    {\n      "code": "11102",\n      "name": "Tangential biopsy of skin",\n      "description": "Tangential biopsy of skin; single lesion",\n      "type": "Assumed Standard",\n      "reason": "Though not directly performed here, biopsy is standard for confirmation or ruling out malignancy in AK or neoplastic areas.",\n      "modifiers": "59",\n      "associated_ICD": ["L57.0", "D48.5"]\n    }\n  ]\n}\n\n'}]

# %% [markdown]
# ```
# {
#   "cpt": [
#     {
#       "code": "96574",
#       "name": "Debridement for photodynamic therapy",
#       "description": "Debridement and curettage of skin prior to photodynamic therapy (PDT)",
#       "relation_type": "Sibling",
#       "relation_with": "96567",
#       "reason": "Same procedural group – 96567 covers the PDT application; 96574 is used when lesion preparation (debridement) is done.",
#       "modifiers": "",
#       "associated_ICD": ["L57.0"]
#     },
#     {
#       "code": "96573",
#       "name": "Photodynamic therapy application only",
#       "description": "Application of photodynamic therapy without lesion preparation",
#       "relation_type": "Sibling",
#       "relation_with": "96567",
#       "reason": "Same code range as 96567. This is an alternate documentation/billing path for PDT when debridement is not performed.",
#       "modifiers": "",
#       "associated_ICD": ["L57.0"]
#     },
#     {
#       "code": "17004",
#       "name": "Destruction of 15 or more premalignant lesions",
#       "description": "Destruction of premalignant lesions (e.g., actinic keratoses); 15 or more lesions",
#       "relation_type": "Sibling",
#       "relation_with": "17003",
#       "reason": "Same CPT series (17000–17004) used when ≥15 premalignant lesions are destroyed. Twenty were treated here.",
#       "modifiers": "",
#       "associated_ICD": ["L57.0"]
#     },
#     {
#       "code": "17000",
#       "name": "Destruction of premalignant lesion (first)",
#       "description": "Destruction of premalignant lesion; first lesion",
#       "relation_type": "Parent Category",
#       "relation_with": "17003",
#       "reason": "17003 must be billed alongside 17000 as a parent code. Together they account for all lesions treated.",
#       "modifiers": "",
#       "associated_ICD": ["L57.0"]
#     },
#     {
#       "code": "15789",
#       "name": "Chemical peel, facial; dermal",
#       "description": "Chemical exfoliation for deeper (dermal) layers, e.g., for severe actinic damage",
#       "relation_type": "Sibling",
#       "relation_with": "15788",
#       "reason": "Same CPT family. 15789 is used when deeper chemical peeling is performed beyond epidermal layer.",
#       "modifiers": "RT",
#       "associated_ICD": ["L57.0", "L85.3"]
#     },
#     {
#       "code": "15792",
#       "name": "Chemical peel; non-facial, epidermal",
#       "description": "Chemical exfoliation of non-facial area (e.g., scalp), epidermal",
#       "relation_type": "Alternate Procedure",
#       "relation_with": "15788",
#       "reason": "Scalp is a non-facial region. This is a better anatomical match than 15788, though less often used in practice.",
#       "modifiers": "RT",
#       "associated_ICD": ["L57.0", "L85.3"]
#     },
#     {
#       "code": "15793",
#       "name": "Chemical peel; non-facial, dermal",
#       "description": "Chemical exfoliation of non-facial area (e.g., scalp), dermal",
#       "relation_type": "Sibling",
#       "relation_with": "15792",
#       "reason": "Deeper dermal version of 15792 — used for extensive actinic or neoplastic damage requiring more aggressive treatment.",
#       "modifiers": "RT",
#       "associated_ICD": ["L57.0", "D48.5"]
#     },
#     {
#       "code": "99204",
#       "name": "Office visit for new patient, moderate complexity",
#       "description": "Office or other outpatient visit for a new patient; 45–59 minutes, moderate complexity",
#       "relation_type": "Sibling",
#       "relation_with": "99203",
#       "reason": "Same E/M category, higher time and complexity bracket. Could be appropriate depending on depth of counseling and management.",
#       "modifiers": "",
#       "associated_ICD": ["Z01.818"]
#     },
#     {
#       "code": "99202",
#       "name": "Office visit for new patient, straightforward",
#       "description": "Office or other outpatient visit for a new patient; 15–29 minutes, straightforward complexity",
#       "relation_type": "Sibling",
#       "relation_with": "99203",
#       "reason": "Lower-complexity visit in same code series. Could apply if visit was less involved than documented.",
#       "modifiers": "",
#       "associated_ICD": ["Z01.818"]
#     },
#     {
#       "code": "11103",
#       "name": "Tangential biopsy, each additional lesion",
#       "description": "Add-on code for tangential biopsy; each additional lesion",
#       "relation_type": "Sibling",
#       "relation_with": "11102",
#       "reason": "Used together with 11102 when more than one lesion is biopsied in the same session.",
#       "modifiers": "59",
#       "associated_ICD": ["L57.0", "D48.5"]
#     }
#   ]
# }
# ```
